# %% [markdown]
# # Tutorial 2: Augment real-world data with TabEBM

# %% [markdown]
# ## Environment setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install tabebm
# !pip install tabcamel
# Out:
# Requirement already satisfied: tabebm in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (2024.10.6)
# Requirement already satisfied: matplotlib in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabebm) (3.10.5)
# Requirement already satisfied: matplotlib-inline in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabebm) (0.1.7)
# Requirement already satisfied: numpy in /home/xj265/.local/lib/python3.10/site-packages (from tabebm) (1.26.4)
# Requirement already satisfied: scipy in /home/xj265/.local/lib/python3.10/site-packages (from tabebm) (1.11.4)
# Requirement already satisfied: tabpfn in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabebm) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (25.0)
# Requirement already satisfied: pillow>=8 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib->tabebm) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xj265/.local/lib/python3.10/site-packages (from matplotlib->tabebm) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->tabebm) (1.17.0)
# Requirement already satisfied: traitlets in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib-inline->tabebm) (5.14.3)
# Requirement already satisfied: torch<3,>=2.1 in /home/xj265/.local/lib/python3.10/site-packages (from tabpfn->tabebm) (2.2.2)
# Requirement already satisfied: scikit-learn<1.7,>=1.2.0 in /home/xj265/.local/lib/python3.10/site-packages (from tabpfn->tabebm) (1.5.2)
# Requirement already satisfied: typing_extensions>=4.12.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabpfn->tabebm) (4.14.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/xj265/.local/lib/python3.10/site-packages (from tabpfn->tabebm) (2.2.2)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabpfn->tabebm) (0.8.1)
# Requirement already satisfied: huggingface-hub<1,>=0.0.1 in /home/xj265/.local/lib/python3.10/site-packages (from tabpfn->tabebm) (0.26.3)
# Requirement already satisfied: pydantic>=2.8.0 in /home/xj265/.local/lib/python3.10/site-packages (from tabpfn->tabebm) (2.10.3)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabpfn->tabebm) (2.10.1)
# Requirement already satisfied: eval-type-backport>=0.2.2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabpfn->tabebm) (0.2.2)
# Requirement already satisfied: filelock in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (6.0.2)
# Requirement already satisfied: requests in /home/xj265/.local/lib/python3.10/site-packages (from huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/xj265/.local/lib/python3.10/site-packages (from huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pandas<3,>=1.4.0->tabpfn->tabebm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/xj265/.local/lib/python3.10/site-packages (from pandas<3,>=1.4.0->tabpfn->tabebm) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/xj265/.local/lib/python3.10/site-packages (from scikit-learn<1.7,>=1.2.0->tabpfn->tabebm) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/xj265/.local/lib/python3.10/site-packages (from scikit-learn<1.7,>=1.2.0->tabpfn->tabebm) (3.4.0)
# Requirement already satisfied: sympy in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (1.14.0)
# Requirement already satisfied: networkx in /home/xj265/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (2.8.8)
# Requirement already satisfied: jinja2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/xj265/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/xj265/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/xj265/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn->tabebm) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3,>=2.1->tabpfn->tabebm) (12.6.85)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/xj265/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->tabpfn->tabebm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/xj265/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->tabpfn->tabebm) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/xj265/.local/lib/python3.10/site-packages (from pydantic-settings>=2.10.1->tabpfn->tabebm) (1.0.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pydantic-settings>=2.10.1->tabpfn->tabebm) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from jinja2->torch<3,>=2.1->tabpfn->tabebm) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xj265/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->huggingface-hub<1,>=0.0.1->tabpfn->tabebm) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sympy->torch<3,>=2.1->tabpfn->tabebm) (1.3.0)
# Requirement already satisfied: tabcamel in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (2025.8.10)
# Requirement already satisfied: bnlearn in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (0.10.2)
# Requirement already satisfied: cloudpickle in /home/xj265/.local/lib/python3.10/site-packages (from tabcamel) (3.0.0)
# Requirement already satisfied: flake8 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (7.3.0)
# Requirement already satisfied: ipykernel in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (6.30.1)
# Requirement already satisfied: myst-parser in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (4.0.1)
# Requirement already satisfied: pgmpy==1.0.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (1.0.0)
# Requirement already satisfied: pylint in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (3.3.8)
# Requirement already satisfied: pytest in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (8.4.1)
# Requirement already satisfied: setuptools==75.1.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (75.1.0)
# Requirement already satisfied: sphinx in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (8.1.3)
# Requirement already satisfied: sphinx-book-theme in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (1.1.4)
# Requirement already satisfied: sphinx-rtd-theme in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (3.0.2)
# Requirement already satisfied: ucimlrepo in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from tabcamel) (0.0.7)
# Requirement already satisfied: networkx in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (2.8.8)
# Requirement already satisfied: numpy in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (1.26.4)
# Requirement already satisfied: scipy in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (1.11.4)
# Requirement already satisfied: scikit-learn in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (1.5.2)
# Requirement already satisfied: pandas in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (2.2.2)
# Requirement already satisfied: torch in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (2.2.2)
# Requirement already satisfied: statsmodels in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (0.14.2)
# Requirement already satisfied: tqdm in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (4.67.1)
# Requirement already satisfied: joblib in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (1.4.2)
# Requirement already satisfied: opt-einsum in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (3.4.0)
# Requirement already satisfied: pyro-ppl in /home/xj265/.local/lib/python3.10/site-packages (from pgmpy==1.0.0->tabcamel) (1.9.0)
# Requirement already satisfied: matplotlib>=3.3.4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (3.10.5)
# Requirement already satisfied: ismember in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.1.0)
# Requirement already satisfied: funcsigs in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.0.2)
# Requirement already satisfied: python-louvain in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (0.16)
# Requirement already satisfied: packaging in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (25.0)
# Requirement already satisfied: df2onehot in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.0.8)
# Requirement already satisfied: fsspec in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (2025.3.0)
# Requirement already satisfied: pypickle in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (2.0.1)
# Requirement already satisfied: tabulate in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (0.9.0)
# Requirement already satisfied: ipywidgets in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (8.1.7)
# Requirement already satisfied: datazets in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.1.3)
# Requirement already satisfied: setgraphviz in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.0.3)
# Requirement already satisfied: lingam in /home/xj265/.local/lib/python3.10/site-packages (from bnlearn->tabcamel) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xj265/.local/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn->tabcamel) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->bnlearn->tabcamel) (1.17.0)
# Requirement already satisfied: requests in /home/xj265/.local/lib/python3.10/site-packages (from datazets->bnlearn->tabcamel) (2.32.3)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from flake8->tabcamel) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from flake8->tabcamel) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from flake8->tabcamel) (3.4.0)
# Requirement already satisfied: comm>=0.1.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/xj265/.local/lib/python3.10/site-packages (from ipykernel->tabcamel) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (5.9.8)
# Requirement already satisfied: pyzmq>=25 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (27.0.1)
# Requirement already satisfied: tornado>=6.2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipykernel->tabcamel) (5.14.3)
# Requirement already satisfied: decorator in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (2.19.2)
# Requirement already satisfied: stack_data in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->tabcamel) (4.14.1)
# Requirement already satisfied: wcwidth in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->tabcamel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->tabcamel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->tabcamel) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->tabcamel) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipywidgets->bnlearn->tabcamel) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from ipywidgets->bnlearn->tabcamel) (3.0.15)
# Requirement already satisfied: graphviz in /home/xj265/.local/lib/python3.10/site-packages (from lingam->bnlearn->tabcamel) (0.20.3)
# Requirement already satisfied: pygam in /home/xj265/.local/lib/python3.10/site-packages (from lingam->bnlearn->tabcamel) (0.9.1)
# Requirement already satisfied: psy in /home/xj265/.local/lib/python3.10/site-packages (from lingam->bnlearn->tabcamel) (0.0.1)
# Requirement already satisfied: semopy in /home/xj265/.local/lib/python3.10/site-packages (from lingam->bnlearn->tabcamel) (2.3.11)
# Requirement already satisfied: docutils<0.22,>=0.19 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from myst-parser->tabcamel) (0.21.2)
# Requirement already satisfied: jinja2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from myst-parser->tabcamel) (3.1.6)
# Requirement already satisfied: markdown-it-py~=3.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from myst-parser->tabcamel) (3.0.0)
# Requirement already satisfied: mdit-py-plugins>=0.4.1,~=0.4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from myst-parser->tabcamel) (0.5.0)
# Requirement already satisfied: pyyaml in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from myst-parser->tabcamel) (6.0.2)
# Requirement already satisfied: mdurl~=0.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from markdown-it-py~=3.0->myst-parser->tabcamel) (0.1.2)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (1.4.1)
# Requirement already satisfied: tomli>=2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx->tabcamel) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from jinja2->myst-parser->tabcamel) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xj265/.local/lib/python3.10/site-packages (from requests->datazets->bnlearn->tabcamel) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->datazets->bnlearn->tabcamel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->datazets->bnlearn->tabcamel) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from requests->datazets->bnlearn->tabcamel) (2025.8.3)
# Requirement already satisfied: pytz>=2020.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pandas->pgmpy==1.0.0->tabcamel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/xj265/.local/lib/python3.10/site-packages (from pandas->pgmpy==1.0.0->tabcamel) (2024.1)
# Requirement already satisfied: progressbar2 in /home/xj265/.local/lib/python3.10/site-packages (from psy->lingam->bnlearn->tabcamel) (4.5.0)
# Requirement already satisfied: python-utils>=3.8.1 in /home/xj265/.local/lib/python3.10/site-packages (from progressbar2->psy->lingam->bnlearn->tabcamel) (3.9.1)
# Requirement already satisfied: astroid<=3.4.0.dev0,>=3.3.8 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pylint->tabcamel) (3.3.11)
# Requirement already satisfied: dill>=0.2 in /home/xj265/.local/lib/python3.10/site-packages (from pylint->tabcamel) (0.3.8)
# Requirement already satisfied: isort!=5.13,<7,>=4.2.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pylint->tabcamel) (6.0.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pylint->tabcamel) (0.13.3)
# Requirement already satisfied: pyro-api>=0.1.1 in /home/xj265/.local/lib/python3.10/site-packages (from pyro-ppl->pgmpy==1.0.0->tabcamel) (0.1.2)
# Requirement already satisfied: filelock in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (3.18.0)
# Requirement already satisfied: sympy in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/xj265/.local/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/xj265/.local/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/xj265/.local/lib/python3.10/site-packages (from torch->pgmpy==1.0.0->tabcamel) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->pgmpy==1.0.0->tabcamel) (12.6.85)
# Requirement already satisfied: iniconfig>=1 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pytest->tabcamel) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pytest->tabcamel) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/xj265/.local/lib/python3.10/site-packages (from scikit-learn->pgmpy==1.0.0->tabcamel) (3.4.0)
# Requirement already satisfied: numdifftools in /home/xj265/.local/lib/python3.10/site-packages (from semopy->lingam->bnlearn->tabcamel) (0.9.41)
# Requirement already satisfied: pydata-sphinx-theme==0.15.4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx-book-theme->tabcamel) (0.15.4)
# Requirement already satisfied: beautifulsoup4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pydata-sphinx-theme==0.15.4->sphinx-book-theme->tabcamel) (4.13.4)
# Requirement already satisfied: accessible-pygments in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from pydata-sphinx-theme==0.15.4->sphinx-book-theme->tabcamel) (0.0.5)
# Requirement already satisfied: soupsieve>1.2 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from beautifulsoup4->pydata-sphinx-theme==0.15.4->sphinx-book-theme->tabcamel) (2.7)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sphinx-rtd-theme->tabcamel) (4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->tabcamel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->tabcamel) (3.0.0)
# Requirement already satisfied: pure-eval in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->tabcamel) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /home/xj265/.local/lib/python3.10/site-packages (from statsmodels->pgmpy==1.0.0->tabcamel) (0.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/xj265/anaconda3/envs/tfm/lib/python3.10/site-packages (from sympy->torch->pgmpy==1.0.0->tabcamel) (1.3.0)

# %%
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from tabcamel.data.dataset import TabularDataset
from tabcamel.data.transform import CategoryTransform, NumericTransform, TargetTransform

from tabebm.TabEBM import TabEBM, seed_everything

# %%
seed_everything(42)

# %% [markdown]
# ## Prepare real-world data

# %% [markdown]
# - Load the dataset

# %%
dataset = TabularDataset(
    dataset_name="adult",
    task_type="classification",
)
print(dataset)
# Out:
# ============================DATA INFO============================
# Dataset: adult
# Task type: classification
# Status (is_tensor): False
# Number of samples: 48842
# Number of features: 14 (Numerical: 2, Categorical: 12)
# Number of classes: 2
# Class distribution: {'<=50K': 0.7607182343065395, '>50K': 0.23928176569346055}
# =================================================================

# %% [markdown]
# - Subsample a small subset of the data to simulate low-sample-size scenario

# %%
subsample_dict = dataset.sample(
    sample_mode="stratified",
    sample_size=200,
    random_state=42,
)
dataset = subsample_dict["dataset_sampled"]

print("Subsampled dataset:")
print(dataset)
# Out:
# Subsampled dataset:
# ============================DATA INFO============================
# Dataset: adult
# Task type: classification
# Status (is_tensor): False
# Number of samples: 200
# Number of features: 14 (Numerical: 2, Categorical: 12)
# Number of classes: 2
# Class distribution: {'<=50K': 0.765, '>50K': 0.235}
# =================================================================

# %% [markdown]
# - Preprocess the data

# %%
# Split the dataset into training and testing sets
split_dict = dataset.split(
    split_mode="stratified",
    train_size=0.8,
    random_state=42,
)
train_set = split_dict["train_set"]
test_set = split_dict["test_set"]
X_train, y_train = train_set.X_df, pd.DataFrame(train_set.y_s)
X_test, y_test = test_set.X_df, pd.DataFrame(test_set.y_s)

# Transform the features
feature_encoder = CategoryTransform(
    categorical_feature_list=train_set.categorical_feature_list,
    strategy="onehot",
)
feature_encoder.fit(X_train)
X_train = feature_encoder.transform(X_train)
X_test = feature_encoder.transform(X_test)

feature_scaler = NumericTransform(
    numerical_feature_list=train_set.numerical_feature_list,
    strategy="standard",
    include_categorical=False,
)
feature_scaler.fit(X_train)
X_train = feature_scaler.transform(X_train)
X_test = feature_scaler.transform(X_test)

target_encoder = TargetTransform(
    task="classification",
    target_feature=train_set.target_col,
)
target_encoder.fit(y_train)
y_train = target_encoder.transform(y_train)
y_test = target_encoder.transform(y_test)

# %% [markdown]
# ## Prepare synthetic data

# %% [markdown]
# * Train TabEBM for synthetic data generation

# %%
# === Fit TabEBM and generate synthetic samples ===
tabebm = TabEBM()
# Generate 50 synthetic samples per class
data_syn = tabebm.generate(X_train, y_train, num_samples=50)

# %% [markdown]
# * Combine synthetic data with real data

# %%
# === Combine the synthetic samples with the real samples ===
X_syn = np.concatenate(list(data_syn.values()))
y_syn = np.concatenate([np.full(len(data_syn[f"class_{i}"]), i) for i in range(len(data_syn.keys()))])

X_train_augmented = np.concatenate([X_train, X_syn])
y_train_augmented = np.concatenate([y_train.to_numpy().reshape(-1), y_syn])

# %% [markdown]
# ## Train a downstream predictor

# %% [markdown]
# ### Original dataset: only real data

# %%
model_vanilla = KNeighborsClassifier()
model_vanilla.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Augmented dataset: real + synthetic data

# %%
model_augmented = KNeighborsClassifier()
model_augmented.fit(X_train_augmented, y_train_augmented)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Evaluate the predictive accuracy

# %%
from sklearn.metrics import balanced_accuracy_score

y_pred_vanilla = model_vanilla.predict(X_test)
y_pred_augmented = model_augmented.predict(X_test)
acc_vanilla = balanced_accuracy_score(y_test, y_pred_vanilla) * 100
acc_augmented = balanced_accuracy_score(y_test, y_pred_augmented) * 100

print(f"Vanilla model's balanced accuracy: {acc_vanilla:.2f}")
print(f"Augmented model's balanced accuracy: {acc_augmented:.2f}")
# Out:
# Vanilla model's balanced accuracy: 71.33
# Augmented model's balanced accuracy: 75.99
